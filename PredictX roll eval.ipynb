# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Flight Distance Test.csv')

# %%
df
# Out:
#                                    Normalised City Pair Departure Code  \
# 0     London, United Kingdom - New York, United Stat...            LHR
# 1     Johannesburg, South Africa - London, United Ki...            JNB
# 2     London, United Kingdom - New York, United Stat...            LHR
# 3     Johannesburg, South Africa - London, United Ki...            JNB
# 4         London, United Kingdom - Singapore, Singapore            SIN
# ...                                                 ...            ...
# 2995  New York, United States Of America - Toronto, ...            LGA
# 2996  Newark, United States Of America - Vail/eagle,...            EGE
# 2997  Isle Of Man, United Kingdom - Southampton, Uni...            SOU
# 2998                   Ottawa, Canada - Toronto, Canada            YYZ
# 2999             Frankfurt, Germany - Helsinki, Finland            HEL
#
#      Arrival Code  Departure_lat  Departure_lon  Arrival_lat  Arrival_lon
# ...

# %%
df.describe()
# Out:
#        Departure_lat  Departure_lon  Arrival_lat  Arrival_lon
# count    3000.000000    3000.000000  3000.000000  3000.000000
# mean       31.573267       4.342753    30.692543     3.584463
# std        23.254100      74.277086    23.835103    74.942567
# min       -37.700000    -157.920000   -41.330000  -157.920000
# 25%        25.300000     -73.790000    22.477500   -73.790000
# 50%        40.100000       2.540000    40.000000     3.320000
# 75%        49.000000      55.350000    47.550000    55.350000
# max        64.000000     153.110000    63.990000   174.810000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Normalised City Pair  3000 non-null   object
#  1   Departure Code        3000 non-null   object
#  2   Arrival Code          3000 non-null   object
#  3   Departure_lat         3000 non-null   float64
#  4   Departure_lon         3000 non-null   float64
#  5   Arrival_lat           3000 non-null   float64
#  6   Arrival_lon           3000 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 164.2+ KB

# %%
depart_city = df.sort_values(by=['Departure Code'], ascending=True)
depart_city.head(50)
# Out:
#                                    Normalised City Pair Departure Code  \
# 2490  Albuquerque, United States Of America - Denver...            ABQ
# 1606  Albuquerque, United States Of America - San Fr...            ABQ
# 2078  Aberdeen, United Kingdom - London, United Kingdom            ABZ
# 1778  Aberdeen, United Kingdom - London, United Kingdom            ABZ
# 876                       Accra, Ghana - Nairobi, Kenya            ACC
# 489                       Accra, Ghana - Nairobi, Kenya            ACC
# 2768                      Accra, Ghana - Lusaka, Zambia            ACC
# 1318              Accra, Ghana - London, United Kingdom            ACC
# 2307  Accra, Ghana - New York, United States Of America            ACC
# 1885             Accra, Ghana - Entebbe/kampala, Uganda            ACC
# 2701                Accra, Ghana - Mauritius, Mauritius            ACC
# 890                       Accra, Ghana - Nairobi, Kenya            ACC
# ...

# %%
depart_city = df.sort_values(by=['Arrival Code'], ascending=True)
depart_city.head(50)
# Out:
#                                    Normalised City Pair Departure Code  \
# 2571  Albuquerque, United States Of America - Dallas...            DFW
# 2775  Albuquerque, United States Of America - San Fr...            SFO
# 2767  Albuquerque, United States Of America - Kansas...            MCI
# 2489  Albuquerque, United States Of America - Dallas...            DFW
# 452             Abuja, Nigeria - London, United Kingdom            LHR
# 2564                    Abuja, Nigeria - Lagos, Nigeria            LOS
# 686   Aberdeen, United Kingdom - London, United Kingdom            LHR
# 1867  Aberdeen, United Kingdom - Dallas, United Stat...            DFW
# 2144         Accra, Ghana - Dubai, United Arab Emirates            DXB
# 2218                        Accra, Ghana - Cairo, Egypt            CAI
# 2446          Accra, Ghana - Johannesburg, South Africa            JNB
# 62                Accra, Ghana - London, United Kingdom            LHR
# ...

# %%
def haversine_np(Departure_lon, Departure_lat, Arrival_lon, Arrival_lat):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.    

    """
    Departure_lon, Departure_lat, Arrival_lon, Arrival_lat = map(np.radians, [Departure_lon, Departure_lat, Arrival_lon, Arrival_lat])

    dlon = Arrival_lon - Departure_lon
    dlat = Arrival_lat - Departure_lat

    a = np.sin(dlat/2.0)**2 + np.cos(Departure_lat) * np.cos(Arrival_lat) * np.sin(dlon/2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    return km

df['distance'] = haversine_np(df['Departure_lon'],df['Departure_lat'],df['Arrival_lon'],df['Arrival_lat'])

# %%
df
# Out:
#                                    Normalised City Pair Departure Code  \
# 0     London, United Kingdom - New York, United Stat...            LHR
# 1     Johannesburg, South Africa - London, United Ki...            JNB
# 2     London, United Kingdom - New York, United Stat...            LHR
# 3     Johannesburg, South Africa - London, United Ki...            JNB
# 4         London, United Kingdom - Singapore, Singapore            SIN
# ...                                                 ...            ...
# 2995  New York, United States Of America - Toronto, ...            LGA
# 2996  Newark, United States Of America - Vail/eagle,...            EGE
# 2997  Isle Of Man, United Kingdom - Southampton, Uni...            SOU
# 2998                   Ottawa, Canada - Toronto, Canada            YYZ
# 2999             Frankfurt, Germany - Helsinki, Finland            HEL
#
#      Arrival Code  Departure_lat  Departure_lon  Arrival_lat  Arrival_lon  \
# ...
